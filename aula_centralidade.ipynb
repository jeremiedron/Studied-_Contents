# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Scientist-ou-Cientista-de-Dados" data-toc-modified-id="Data-Scientist-ou-Cientista-de-Dados-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Scientist ou Cientista de Dados</a></span></li><li><span><a href="#O-que-é-Ciência?" data-toc-modified-id="O-que-é-Ciência?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>O que é Ciência?</a></span></li><li><span><a href="#Método-Científico" data-toc-modified-id="Método-Científico-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Método Científico</a></span></li><li><span><a href="#Estatística" data-toc-modified-id="Estatística-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Estatística</a></span><ul class="toc-item"><li><span><a href="#História-da-Estatística" data-toc-modified-id="História-da-Estatística-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>História da Estatística</a></span></li></ul></li><li><span><a href="#O-que-é-Análise-exploratória-de-Dados?" data-toc-modified-id="O-que-é-Análise-exploratória-de-Dados?-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>O que é Análise exploratória de Dados?</a></span><ul class="toc-item"><li><span><a href="#Etapas" data-toc-modified-id="Etapas-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Etapas</a></span></li><li><span><a href="#Problema:" data-toc-modified-id="Problema:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Problema:</a></span></li></ul></li><li><span><a href="#ANACONDA" data-toc-modified-id="ANACONDA-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>ANACONDA</a></span></li><li><span><a href="#JUPYTER" data-toc-modified-id="JUPYTER-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>JUPYTER</a></span></li><li><span><a href="#GIT" data-toc-modified-id="GIT-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>GIT</a></span></li><li><span><a href="#Abrindo-o-arquivo-e-acessando-os-dados" data-toc-modified-id="Abrindo-o-arquivo-e-acessando-os-dados-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Abrindo o arquivo e acessando os dados</a></span></li><li><span><a href="#Medidas-de-Centralidade" data-toc-modified-id="Medidas-de-Centralidade-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Medidas de Centralidade</a></span><ul class="toc-item"><li><span><a href="#Média" data-toc-modified-id="Média-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Média</a></span></li><li><span><a href="#Fazendo-a-média-com-nosso-arquivo-original" data-toc-modified-id="Fazendo-a-média-com-nosso-arquivo-original-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Fazendo a média com nosso arquivo original</a></span></li><li><span><a href="#Calculando-a-média-de-Salario,-anos-de-estudo-e-idade-no-mesmo-código." data-toc-modified-id="Calculando-a-média-de-Salario,-anos-de-estudo-e-idade-no-mesmo-código.-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Calculando a média de Salario, anos de estudo e idade no mesmo código.</a></span></li><li><span><a href="#melhor-opção-para-resolver-os-zeros" data-toc-modified-id="melhor-opção-para-resolver-os-zeros-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>melhor opção para resolver os zeros</a></span></li><li><span><a href="#Uma-segunda-opção-para-resolver-os-zeros" data-toc-modified-id="Uma-segunda-opção-para-resolver-os-zeros-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>Uma segunda opção para resolver os zeros</a></span></li><li><span><a href="#Mediana" data-toc-modified-id="Mediana-10.6"><span class="toc-item-num">10.6&nbsp;&nbsp;</span>Mediana</a></span></li><li><span><a href="#Aprendendo-a-trabalhar-com-dicionários-em-Python" data-toc-modified-id="Aprendendo-a-trabalhar-com-dicionários-em-Python-10.7"><span class="toc-item-num">10.7&nbsp;&nbsp;</span>Aprendendo a trabalhar com dicionários em Python</a></span></li><li><span><a href="#Definindo-uma-função-para-calcular-a-Mediana" data-toc-modified-id="Definindo-uma-função-para-calcular-a-Mediana-10.8"><span class="toc-item-num">10.8&nbsp;&nbsp;</span>Definindo uma função para calcular a Mediana</a></span></li><li><span><a href="#Aplicando-para-as-idades-do-nosso-DataSet" data-toc-modified-id="Aplicando-para-as-idades-do-nosso-DataSet-10.9"><span class="toc-item-num">10.9&nbsp;&nbsp;</span>Aplicando para as idades do nosso DataSet</a></span></li><li><span><a href="#Moda" data-toc-modified-id="Moda-10.10"><span class="toc-item-num">10.10&nbsp;&nbsp;</span>Moda</a></span></li><li><span><a href="#Calculando-a-moda" data-toc-modified-id="Calculando-a-moda-10.11"><span class="toc-item-num">10.11&nbsp;&nbsp;</span>Calculando a moda</a></span></li><li><span><a href="#Vamos-criar-uma-função-para-procurar-a-pessoa-mais-velha-da-base" data-toc-modified-id="Vamos-criar-uma-função-para-procurar-a-pessoa-mais-velha-da-base-10.12"><span class="toc-item-num">10.12&nbsp;&nbsp;</span>Vamos criar uma função para procurar a pessoa mais velha da base</a></span></li><li><span><a href="#Como-criar-uma-função-para-procurar-a-pessoa-mais-nova-da-base?" data-toc-modified-id="Como-criar-uma-função-para-procurar-a-pessoa-mais-nova-da-base?-10.13"><span class="toc-item-num">10.13&nbsp;&nbsp;</span>Como criar uma função para procurar a pessoa mais nova da base?</a></span></li></ul></li><li><span><a href="#Prévia-da-resposta-para-o-nosso-problema.-Os-homens-ganham-mais-do-que-as-mulheres?-Quanto?" data-toc-modified-id="Prévia-da-resposta-para-o-nosso-problema.-Os-homens-ganham-mais-do-que-as-mulheres?-Quanto?-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Prévia da resposta para o nosso problema. Os homens ganham mais do que as mulheres? Quanto?</a></span><ul class="toc-item"><li><span><a href="#Para-este-DataSet,-em-média-as-mulheres-ganham-mais-que-os-homens." data-toc-modified-id="Para-este-DataSet,-em-média-as-mulheres-ganham-mais-que-os-homens.-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Para este DataSet, em média as mulheres ganham mais que os homens.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introdução ao Data Science
#
# Data Science é o estudo disciplinado dos dados e informações inerentes ao negócio e todas as visões que podem cercar um determinado assunto. É uma ciência que estuda as informações, seu processo de captura, transformação, geração e, posteriormente, análise de dados. A ciência de dados envolve diversas disciplinas:
#
# - Computação;
# - Estatística;
# - Conhecimento do Negócio.
#
# <br>
# <img src="img/processo_datascience.png" width="600">
# <br>
#
#
# ## Data Scientist ou Cientista de Dados
#
# O cientista de dados é um profissional multidisciplinar, responsável por realizar o processo citado no tópico Data Science acima. Ou seja, é responsável por transformar dados em informações ou produtos de informações dentro de uma corporação.
#
# Além disso, ele também deve ser responsável pela formulação dos problemas, escolha de modelos de simulação e estatística e entrega dos produtos de dados.
#
#
# ## O que é Ciência?
#
# Ciência representa todo o conhecimento adquirido através do estudo, pesquisa ou da prática, baseado em princípios certos. Esta palavra deriva do latim scientia, cujo significado é "conhecimento" ou "saber".
#
# Em geral, a ciência, que é muito ampla, comporta vários conjuntos de saberes nos quais são elaboradas as suas teorias baseadas nos seus próprios métodos e pesquisas científicas.
#
# A palavra ciência possui vários sentidos, abrangendo principalmente três acepções:
#
# - Saber, conhecimento de certas coisas que servem à condução da vida ou à dos negócios.
# - Conjunto dos conhecimentos adquiridos pelo estudo ou pela prática.
# - Hierarquização, organização e síntese dos conhecimentos através de modelos e princípios gerais (teorias, leis, etc.).
#
# Cita-se de passagem que o próprio conceito de teoria tem várias acepções não específicas que mostram-se muito distintas da que é encontrada em um meio científico, sendo entre estas certamente conhecida a acepção em senso comum de teoria como algo duvidoso, não provado, descartável. Esta acepção e correlatas mostram-se contudo radicalmente diferente da acepção de teoria científica ao considerar-se a acepção stricto sensu da palavra ciência.
#
# ## Método Científico
#
# O método científico refere-se a um aglomerado de regras básicas dos procedimentos que produzem o conhecimento científico, quer um novo conhecimento, quer uma correção (evolução) ou um aumento na área de incidência de conhecimentos anteriormente existentes. Na maioria das disciplinas científicas consiste em juntar evidências empíricas verificáveis — baseadas na observação sistemática e controlada, geralmente resultantes de experiências ou pesquisa de campo — e analisá-las com o uso da lógica. Para muitos autores, o método científico nada mais é do que a lógica aplicada à ciência. Os métodos que fornecem as bases lógicas ao conhecimento científico são: método indutivo, método dedutivo, método hipotético-dedutivo, método dialético, método fenomenológico, etc.
#
# <br>
# <img src="img/metodo_cientifico.png" width="600">
# <br>

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/q40uPdnyhp0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /Users/DataScience/anaconda3/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/q40uPdnyhp0" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Estatística
#
# Estatística é a ciência que se utiliza das teorias probabilísticas para explicar a frequência da ocorrência de eventos, tanto em estudos observacionais quanto em experimentos para modelar a aleatoriedade e a incerteza de forma a estimar ou possibilitar a previsão de fenômenos futuros, conforme o caso.
#
# A estatística é uma ciência que se dedica à coleta, análise e interpretação de dados. Preocupa-se com os métodos de recolha, organização, resumo, apresentação e interpretação dos dados, assim como tirar conclusões sobre as características das fontes donde estes foram retirados, para melhor compreender as situações.
#
# Algumas práticas estatísticas incluem, por exemplo, o planejamento, a sumarização e a interpretação de observações. Dado que o objetivo da estatística é a produção da melhor informação possível a partir dos dados disponíveis, alguns autores sugerem que a estatística é um ramo da teoria da decisão
#
# ### História da Estatística
#
# De acordo com a Revista do Instituto Internacional de Estatística, Cinco homens, Hermann Conring, Gottfried Achenwall, Johann Peter Süssmilch, John Graunt e William Petty já receberam a honra de serem chamados de fundadores da estatística por diferentes autores.
#
# Alguns autores dizem que é comum encontrar como marco inicial da estatística a publicação do "Observations on the Bills of Mortality" (Observações sobre os Censos de Mortalidade, 1662) de John Graunt. As primeiras aplicações do pensamento estatístico estavam voltadas para as necessidades de Estado, na formulação de políticas públicas, fornecendo dados demográficos e econômicos. A abrangência da estatística aumentou no começo do século XIX para incluir a acumulação e análise de dados de maneira geral. Hoje, a estatística é largamente aplicada nas ciências naturais, e sociais, inclusive na administração pública e privada.
#
# Seus fundamentos matemáticos foram postos no século XVII com o desenvolvimento da teoria das probabilidades por Pascal e Fermat, que surgiu com o estudo dos jogos de azar. O método dos mínimos quadrados foi descrito pela primeira vez por Carl Friedrich Gauss, aproximadamente no ano de 1794. O uso de computadores modernos tem permitido a computação de dados estatísticos em larga escala e também tornaram possível novos métodos antes impraticáveis.
#
# Porém, Galton foi o precursos de teorias que foram inicilamente chamadas de "regressão à média", resultante do estudo sobre as alturas das pessoas, que permitiu concluir que filhos de pais muito altos tendem a ser mais baixos que seus pais, e filhos de pais muito baixos tendem a ser mais altos, fazendo com que a estatura humana se afaste dos extremos e se aproxime da média, derivando a uma medida matemática chamada de "coeficiente de correlação", depois consagrado por Pearson e que foi capaz de mudar a ciência.
#
# Através de seus estudos de medição, Galton também foi capaz de verificar o comportamento da distribuição dos valores de uma variável qualquer com resultados aleatórios, verificando desvios entre valores observados e previstos, cujos ERROS ou pequenos desvios apresentavam-se numa distribuição por uma "curva em forma de sino", descritas por uma função matemática, com quatro parâmetros principais:
#
# 1. Média - valor central a partir do qual as medições se dispersam
# 2. Desvio Padrão - o quanto a maioria das medições se dispersa em torno da mádia
# 3. Simetria - o grau em que as medições se acumulam am apenas um lado da média
# 4. Curtose - o quanto as medições raras se afastam da média
#
# Como exemplos comprobatórios, temos as leis de Kepler que descreviam o movimento dos planetas no espaço, e as experiências de Harvey sobre como o sangue percorre as veias e artérias de um animal. Este fato foi o que posteriormente Pearson tratou como fenômenos observáveis com meros reflexos aleatórios, cujos quatro parâmetros mencionados poderiam ser determinados por investigação científica, sendo possível estimá-los por meio de dados.
#
# <br>
# <img src="img/educacao_estatistica.png" width="600">
# <br>

# %% [markdown]
# # Análise exploratória de dados
#
# <br>
# <img src="img/EDA.jpg">
# <br>
#
#
# ## O que é Análise exploratória de Dados?
#
# Em estatística, a **análise exploratória de dados (AED)** é uma abordagem à análise de conjuntos de dados de modo a resumir suas características principais, frequentemente com métodos visuais. Um modelo estatístico pode ou não ser usado, mas primariamente a AED tem como objetivo observar o que os dados podem nos dizer além da modelagem formal ou do processo de teste de hipóteses. A análise exploratória de dados foi promovida pelo estatístico norte-americano John Tukey, que incentivava os estatísticos a explorar os dados e possivelmente formular hipóteses que poderiam levar a novas coletas de dados e experimentos. A **AED** é diferente da análise inicial de dados (AID), que se concentra mais estreitamente em verificar os pressupostos exigidos para ajuste de modelos e teste de hipóteses, além de manusear valores faltantes e fazer transformações de variáveis conforme necessário. A análise exploratória de dados abrange a AID.
#
# A análise exploratória de dados emprega grande variedade de técnicas gráficas e quantitativas, visando maximizar a obtenção de informações ocultas na sua estrutura, descobrir variáveis importantes em suas tendências, detectar comportamentos anômalos do fenômeno, testar se são válidas as hipóteses assumidas, escolher modelos e determinar o número ótimo de variáveis.
#
# Os softwares atualmente disponíveis possibilitam que esta técnica se constitua em uma ferramenta para descobrir quais tendências, relações e padrões podem estar ocultos em uma coleção de dados analisados. Seguindo as diretrizes propostas por Tukey, os investigadores deveriam iniciar sua análise pelo exame dos dados disponíveis e depois decidir qual técnica aplicar para resolver o problema.
#
# ### Etapas
#
# (Existe vários frameworks diferentes com essas etapas, e certamenta alguns funcionam melhor que outros dependendo do problema enfrentado. Até mesmo as perguntas mais elementares como "Entendendo o Problema" pode ser que não exista em algum caso especifico, então usem como um guia, não como a verdade).
#
# Etapas básicas:
#
# 1. **Entendendo o Problema**. De longe a etapa mais importante e potêncialmente a mais dificil do problema
#
# 2. **Entendendo os Dados**. Na aula de hoje focaremos nesta etapa. Faremos um overview sobre os dados e analisaremos as medidas de centralidade.
#
# 3. **Analise Univariada**. Na próxima aula iremos um pouco além, entendendo mais a fundo as estatisticas descritivas dos dados.
#
# 4. **Outliers, Nulos e outros**. Nessa etapa, trataremos os dados para que façam sentido para os nossos algoritmos.
#
# 5. **Analise Multivariada**. Aqui vamos entender como as variaveis estão relacionadas entre si.
#
# 6. **Inferências e Relações Causais**. Por último vamos responder nossa pergunta
#
#
#
#
# ### Problema:
#
# - Muito se fala de desigualdade salarial entre generos. Existe desigualdade? E se sim, de quanto ela é?

# %% [markdown]
# # Ferramentas
#
# ## ANACONDA
#
# <br>
# <img src="img/anaconda.png" width='500' >
# <br>
#
# A plataforma abeta Anaconda Distribution é a maneira mais fácil de trabalhar com ciência de dados e aprendizado de máquina em Python/R no Linux, Windows e Mac OS X. Com mais de 11 milhões de usuários em todo o mundo, é o padrão da indústria para desenvolvimento, teste e treinamento de uma única máquina, permitindo que os cientistas de dados individuais:
#
# - Baixar rapidamente mais de 1.500 pacotes de ciência de dados do Python/R
# - Gerenciar bibliotecas, dependências e ambientes com o Conda
# - Desenvolver e treinar modelos de aprendizado de máquina e aprendizagem profunda com Scikit-learn, TensorFlow e Theano
# - Analisar dados com escalabilidade e desempenho com o Dask, NumPy, pandas e Numba
# - Visualizar resultados com Matplotlib, Bokeh, Datashader e Holoviews
#
# Para baixar o ANACONDA [clique aqui](https://www.anaconda.com/distribution/)

# %% [markdown]
# ## JUPYTER
#
# <br>
# <img src="img/jupyter.png" width='75'>
# <br>
#
#
# O Jupyter Notebook é um aplicativo da Web de código aberto que permite criar e compartilhar documentos que contêm código ativo, equações, visualizações e texto narrativo. Os usos incluem: limpeza e transformação de dados, simulação numérica, modelagem estatística, visualização de dados, aprendizado de máquina e muito mais.

# %% [markdown]
# ## GIT
#
# <br>
# <img src="img/git_logo.png" width='200'>
# <br>
#
# *fonte:Wikipedia*
#
# Git pronunciado /git/ (ou pronunciado /dit/ em inglês britânico) é um sistema de controle de versões distribuído, usado principalmente no desenvolvimento de software, mas pode ser usado para registrar o histórico de edições de qualquer tipo de arquivo. O Git foi inicialmente projetado e desenvolvido por Linus Torvalds para o desenvolvimento do kernel Linux, mas foi adotado por muitos outros projetos.
#
# Cada diretório de trabalho do Git é um repositório com um histórico completo e habilidade total de acompanhamento das revisões, não dependente de acesso a uma rede ou a um servidor central. O Git também facilita a reprodutibilidade científica em uma ampla gama de disciplinas, da ecologia à bioinformática, arqueologia à zoologia.
#
# O Git é um software livre, distribuído sob os termos da versão 2 da GNU General Public License. Sua manutenção é atualmente supervisionada por Junio Hamano.
#
# <br>
# <img src="img/git.png" width='600'>
# <br>

# %% [markdown]
# ## Abrindo o arquivo e acessando os dados

# %%
import csv


with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    print(type(data))
# Out:
# <class '_csv.reader'>

# %%
with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    contador = 0
    for row in data:
        print(row)
        contador = contador + 1
        
#         print(row[2],row[4],row[6])
        if contador == 10:
            break
# Out:
# ['seq', 'id', 'idade', 'sexo', 'anos_estudo', 'cor/raca', 'salario', 'estado_civil', 'regiao']
# ['0', '11001901101.0', '53', 'homem', '5.0', 'Parda', '63600.0', '1.0', 'norte']
# ['1', '11001901102.0', '49', 'mulher', '8.0', 'Amarela', '', '1.0', 'norte']
# ['2', '11001901103.0', '22', 'mulher', '11.0', 'Indigena', '4352.400390625', '0.0', 'nordeste']
# ['3', '11001903101.0', '55', 'homem', '15.0', 'Amarela', '96600.0', '1.0', 'norte']
# ['4', '11001903102.0', '56', 'mulher', '15.0', 'Amarela', '157800.0', '1.0', 'norte']
# ['5', '11001903103.0', '30', 'mulher', '15.0', 'Amarela', '88550.0', '0.0', 'nordeste']
# ['6', '11001904101.0', '52', 'mulher', '5.0', 'Branca', '6734.400390625', '0.0', 'norte']
# ['7', '11001904104.0', '29', 'homem', '5.0', 'Parda', '14875.20068359375', '0.0', 'norte']
# ['8', '11001904105.0', '29', 'mulher', '11.0', 'Parda', '6734.400390625', '0.0', 'norte']

# %%
type(row)
# Out:
# list

# %%
type(row[1])
# Out:
# str

# %%
row[1]
# Out:
# '11001904105.0'

# %% [markdown]
# ## Medidas de Centralidade
#
# ### Média
#
#
# *fonte: Wikipedia*
#
# Em estatística, média é definida como o valor que mostra para onde se concentram os dados de uma distribuição como o ponto de equilíbrio das frequências em um histograma. Média também é interpretada como um valor significativo de uma lista de números. Os valores de uma lista de números podem ser representados por meio da escolha aleatória de um número. Se todos os números forem iguais, o número escolhido aleatoriamente será a média. Então, a média pode ser calculada por meio da combinação dos números de maneira específica e da geração de um valor significativo. Entretanto, a palavra média é usualmente usada em métodos mais sofisticados como média aritmética, mediana, moda, entre outros.
#
# Seguindo uma definição mais informal de "média", pode-se assumir que no campo da estatística, dados possuem posições. Por exemplo, cada valor dos lançamentos de um dado possui sua posição em uma planilha eletrônica. Em estatística, média é uma medida de posição que indica um valor uniforme dos dados. Por exemplo, o conjunto x = { 2 , 1 , 6 , 5 , 10 } possui média aritmética 4,8. Embora 4,8 seja o valor médio, ele não é o valor central definido pela mediana.
#
#
# <br>
# <img src="img/media.png">
# <br>
#
#
# A **média** é calculada por:
#
# $$ \overline x = \frac{1}{n} \sum_i x_i $$
#
# Por exemplo, para a mostra 8, 5, 3, -1, e -5, a média é:

# %%
numbers = [8,5,3,-1,-5]

somatorio = 0
for number in numbers:
    somatorio += number
    print(f'Somando {number} + {somatorio-number} = {somatorio}')
    
media = somatorio/len(numbers)
print('\nmédia:',media)
# Out:
# Somando 8 + 0 = 8
# Somando 5 + 8 = 13
# Somando 3 + 13 = 16
# Somando -1 + 16 = 15
# Somando -5 + 15 = 10
#
# média: 2.0

# %% [markdown]
# ### Fazendo a média com nosso arquivo original

# %%
with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    lista_exemplo = []
    somatorio = 0
    for i, line in enumerate(data):
        if  i>0:
            somatorio +=  int(line[2])
            lista_exemplo.append(line[2])
            

media = round(somatorio/len(lista_exemplo),2)

print(f'Média da coluna Idade: {media}')
# Out:
# Média da coluna Idade: 37.63

# %% [markdown]
# ### Calculando a média de Salario, anos de estudo e idade no mesmo código.

# %%
somatorio_idade = 0
somatorio_estudo = 0
somatorio_salario = 0


with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    lista_exemplo = []
    somatorio = 0
    for i, row in enumerate(data):
        if i>0:
            print(row)
            somatorio_idade += int(row[2])
            somatorio_estudo += float(row[4])
            somatorio_salario += float(row[6])
            
        
media_idade = round(somatorio_idade/i,2)
media_estudo = round(somatorio_estudo/i,2)
media_salario = round(somatorio_salario/i,2)


print(f'Média da coluna Idade: {media_idade}')
print(f'Média da coluna Anos de Estudo: {media_estudo}')
print(f'Média da coluna Salario: {media_salario}')
# Out:
# ['0', '11001901101.0', '53', 'homem', '5.0', 'Parda', '63600.0', '1.0', 'norte']
# ['1', '11001901102.0', '49', 'mulher', '8.0', 'Amarela', '', '1.0', 'norte']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4e87affea75f> in <module>
#      14             somatorio_idade += int(row[2])
#      15             somatorio_estudo += float(row[4])
# ---> 16             somatorio_salario += float(row[6])
#      17
#      18
#
# ValueError: could not convert string to float:

# %%
# As linhas NULAS não podem ser convertidas em valores números?
# Como resolver ? Podemos criar uma FUNÇÃO que resolve isso?

# %% [markdown]
# ### melhor opção para resolver os zeros

# %%
def tira_zero(parametro):
    try:
        parametro = float(parametro)
        return parametro
    except:
        return 0

# %%
somatorio_idade = 0
somatorio_estudo = 0
somatorio_salario = 0


with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    somatorio = 0
    
    for i, row in enumerate(data):
        
        if i>0:
            somatorio_idade += tira_zero(row[2])
            somatorio_estudo += tira_zero(row[4])
            somatorio_salario += tira_zero(row[6])
            
media_idade = round(somatorio_idade/i,2)
media_estudo = round(somatorio_estudo/i,2)
media_salario = round(somatorio_salario/i,2)

print(f'Média da coluna Idade: {media_idade}')
print(f'Média da coluna Anos de Estudo: {media_estudo}')
print(f'Média da coluna Salario: {media_salario}')
# Out:
# Média da coluna Idade: 37.63
# Média da coluna Anos de Estudo: 8.63
# Média da coluna Salario: 14194.7

# %% [markdown]
# ### Uma segunda opção para resolver os zeros

# %%
def substitui_nulo_por_zero(entrada):
    
    lista = []
    for i, row in enumerate(entrada):
        if i > 0:
            
            if not row[2]:
                row[2] = 0
                
            if not row[4]:
                row[4] = 0
                
            if not row[6]:
                row[6] = 0
                
            lista.append(row)
            
    return lista

# %%
somatorio_idade = 0
somatorio_estudo = 0
somatorio_salario = 0


with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    lista_exemplo = []
    lista_exemplo = substitui_nulo_por_zero(data)
    
    somatorio = 0
    
    for i, row in enumerate(lista_exemplo):
        
        if i>0:
            somatorio_idade += int(row[2])
            somatorio_estudo += float(row[4])
            somatorio_salario += float(row[6])
            
media_idade = round(somatorio_idade/i,2)
media_estudo = round(somatorio_estudo/i,2)
media_salario = round(somatorio_salario/i,2)

print(f'Média da coluna Idade: {media_idade}')
print(f'Média da coluna Anos de Estudo: {media_estudo}')
print(f'Média da coluna Salario: {media_salario}')
# Out:
# Média da coluna Idade: 37.63
# Média da coluna Anos de Estudo: 8.63
# Média da coluna Salario: 14193.96

# %% [markdown]
# ### Mediana
#
#
#
# Mediana é o valor que separa a metade maior e a metade menor de uma amostra, uma população ou uma distribuição de probabilidade. Em termos mais simples, mediana pode ser o valor do meio de um conjunto de dados. No conjunto de dados {1, 3, 3, 6, 7, 8, 9}, por exemplo, a mediana é 6. Se houver um número par de observações, não há um único valor do meio. Então, a mediana é definida como a média dos dois valores do meio. No conjunto de dados {3, 5, 7, 9}, a mediana é (5 + 7) / 2 = 6.
#
# A mediana é uma medida comum das propriedades de conjuntos de dados em estatística e em teoria das probabilidades, com importância central na estatística robusta. A estatística robusta é mais resistente, com ponto de ruptura de 50%. A mediana não fornece resultados arbitrariamente grandes desde que mais da metade dos dados não esteja contaminada.
#
# A vantagem da mediana em relação à média é que a mediana pode dar uma ideia melhor de um valor típico porque não é tão distorcida por valores extremamente altos ou baixos. Em estudos estatísticos sobre renda familiar ou outros ativos voláteis, a média pode ser distorcida por um pequeno número de valores extremamente altos ou baixos.
#
# Exemplos:
#
# - Ímpar:
# 		[1, 2, 3, 5, 7, 8, 9, 10, 15]
# 		#elementos: 9
# 		A mediana é o valor da posição 5 (a posição do “meio”)
# 		Mediana =  7
#
#
# - Par:
# 		[-5, -1, 0, 1, 2, 3, 8, 20]
# 		#elementos: 8
# 		A mediana é a média dos valores nas duas posições centrais
# 		Mediana =  (1+2)/2 = 1.5

# %% [markdown]
# Material complementar para dicionarios python: http://excript.com/python/funcoes-dicionarios.html

# %% [markdown]
# ### Aprendendo a trabalhar com dicionários em Python

# %%
input_file = csv.DictReader(open(r'data/data.csv', 'r') )

contador = 0
for row in input_file:
    contador += 1
    if contador <= 10:
        print('\n', row)
# Out:
#  OrderedDict([('seq', '0'), ('id', '11001901101.0'), ('idade', '53'), ('sexo', 'homem'), ('anos_estudo', '5.0'), ('cor/raca', 'Parda'), ('salario', '63600.0'), ('estado_civil', '1.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '1'), ('id', '11001901102.0'), ('idade', '49'), ('sexo', 'mulher'), ('anos_estudo', '8.0'), ('cor/raca', 'Amarela'), ('salario', ''), ('estado_civil', '1.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '2'), ('id', '11001901103.0'), ('idade', '22'), ('sexo', 'mulher'), ('anos_estudo', '11.0'), ('cor/raca', 'Indigena'), ('salario', '4352.400390625'), ('estado_civil', '0.0'), ('regiao', 'nordeste')])
#
#  OrderedDict([('seq', '3'), ('id', '11001903101.0'), ('idade', '55'), ('sexo', 'homem'), ('anos_estudo', '15.0'), ('cor/raca', 'Amarela'), ('salario', '96600.0'), ('estado_civil', '1.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '4'), ('id', '11001903102.0'), ('idade', '56'), ('sexo', 'mulher'), ('anos_estudo', '15.0'), ('cor/raca', 'Amarela'), ('salario', '157800.0'), ('estado_civil', '1.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '5'), ('id', '11001903103.0'), ('idade', '30'), ('sexo', 'mulher'), ('anos_estudo', '15.0'), ('cor/raca', 'Amarela'), ('salario', '88550.0'), ('estado_civil', '0.0'), ('regiao', 'nordeste')])
#
#  OrderedDict([('seq', '6'), ('id', '11001904101.0'), ('idade', '52'), ('sexo', 'mulher'), ('anos_estudo', '5.0'), ('cor/raca', 'Branca'), ('salario', '6734.400390625'), ('estado_civil', '0.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '7'), ('id', '11001904104.0'), ('idade', '29'), ('sexo', 'homem'), ('anos_estudo', '5.0'), ('cor/raca', 'Parda'), ('salario', '14875.20068359375'), ('estado_civil', '0.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '8'), ('id', '11001904105.0'), ('idade', '29'), ('sexo', 'mulher'), ('anos_estudo', '11.0'), ('cor/raca', 'Parda'), ('salario', '6734.400390625'), ('estado_civil', '0.0'), ('regiao', 'norte')])
#
#  OrderedDict([('seq', '9'), ('id', '11001905101.0'), ('idade', '46'), ('sexo', 'mulher'), ('anos_estudo', '15.0'), ('cor/raca', 'Branca'), ('salario', '54300.0'), ('estado_civil', '1.0'), ('regiao', 'norte')])

# %%
row
# Out:
# OrderedDict([('seq', '66469'),
#              ('id', '53117018102.0'),
#              ('idade', '37'),
#              ('sexo', 'homem'),
#              ('anos_estudo', '5.0'),
#              ('cor/raca', 'Preta'),
#              ('salario', '460.3500061035156'),
#              ('estado_civil', '1.0'),
#              ('regiao', 'centro-oeste')])

# %%
row['idade']
# Out:
# '37'

# %%
row['regiao']
# Out:
# 'centro-oeste'

# %% [markdown]
# Criando a tabela como um dicionario

# %%
row
# Out:
# OrderedDict([('seq', '66469'),
#              ('id', '53117018102.0'),
#              ('idade', '37'),
#              ('sexo', 'homem'),
#              ('anos_estudo', '5.0'),
#              ('cor/raca', 'Preta'),
#              ('salario', '460.3500061035156'),
#              ('estado_civil', '1.0'),
#              ('regiao', 'centro-oeste')])

# %%
dict_table = dict()
dict_table = {}

with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    header = next(data, None)
    
    for row in data:    
        dict_table[row[1]] = {'idade':row[2], 'sexo':row[3], 'anos_estudo':row[4], 'salario': row[6]}

# %%
dict_table
# Out:
# {'11001901101.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '63600.0'},
#  '11001901102.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11001901103.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '4352.400390625'},
#  '11001903101.0': {'idade': '55',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '96600.0'},
#  '11001903102.0': {'idade': '56',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '157800.0'},
#  '11001903103.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '88550.0'},
#  '11001904101.0': {'idade': '52',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '6734.400390625'},
#  '11001904104.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '14875.20068359375'},
#  '11001904105.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6734.400390625'},
#  '11001905101.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '54300.0'},
#  '11001905102.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '42768.0'},
#  '11001905103.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': '34500.0'},
#  '11001907101.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '981.0'},
#  '11001907102.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '1581.5999755859375'},
#  '11001908101.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '5136.0'},
#  '11001908102.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11001909101.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11001910101.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '3712.0'},
#  '11001911101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '10256.7998046875'},
#  '11001911102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '378.0'},
#  '11001912102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '15187.19921875'},
#  '11001912103.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': ''},
#  '11002702101.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '16560.0'},
#  '11002702102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '7792.19970703125'},
#  '11002703101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '8904.0'},
#  '11002703102.0': {'idade': '36',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '2805.2000122070312'},
#  '11002704101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '24564.0'},
#  '11002704102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '31044.0'},
#  '11002706101.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '5550.0'},
#  '11002706102.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11002707101.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '38844.2783203125'},
#  '11002707102.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '2034.0'},
#  '11002708101.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '2476.47998046875'},
#  '11002708102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11002709101.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '7062.0'},
#  '11002710101.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '4240.0'},
#  '11002710102.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '7233.240234375'},
#  '11002710103.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '5428.2001953125'},
#  '11002711103.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '2180.0'},
#  '11002711104.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '5203.60009765625'},
#  '11002713101.0': {'idade': '55',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '5328.599609375'},
#  '11002713102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '723.2000122070312'},
#  '11003501101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '24564.0'},
#  '11003501102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11003502101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '15960.0'},
#  '11003505101.0': {'idade': '58',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11003506101.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '5940.0'},
#  '11003507101.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6300.0'},
#  '11003508101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '13080.0'},
#  '11003508102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '2199.0'},
#  '11003510101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '24091.2001953125'},
#  '11003510103.0': {'idade': '47',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11003510104.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11003511101.0': {'idade': '37',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '52320.0'},
#  '11003511102.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11003513101.0': {'idade': '58',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '15120.0'},
#  '11003513102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '0.0'},
#  '11004302101.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '3780.0'},
#  '11004303102.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '23674.80078125'},
#  '11004304101.0': {'idade': '46',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '23544.0'},
#  '11004304102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '23544.0'},
#  '11004305103.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '8652.0'},
#  '11004305104.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11004307101.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '6489.0'},
#  '11004312101.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '19080.0'},
#  '11004313101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '10747.80078125'},
#  '11005101102.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '3985.449951171875'},
#  '11005101103.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '3195.5'},
#  '11005101104.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '31392.0'},
#  '11005102101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '13812.48046875'},
#  '11005103101.0': {'idade': '41',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11005103102.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11005103103.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '1278.0'},
#  '11005103104.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': '1291.5'},
#  '11005103105.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '3270.0'},
#  '11005103106.0': {'idade': '21',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '1726.4000244140625'},
#  '11005103107.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11005103110.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11005104101.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '3296.0'},
#  '11005104102.0': {'idade': '46',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11005104103.0': {'idade': '21',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11005104106.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5288.400390625'},
#  '11005105101.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5129.400390625'},
#  '11005106101.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '5179.2001953125'},
#  '11005106102.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11005106103.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '13.0',
#   'salario': '6104.0'},
#  '11005106105.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11005107101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '6092.099853515625'},
#  '11005107102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '9450.0'},
#  '11005108101.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': ''},
#  '11005108102.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': '21624.0'},
#  '11005108103.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11005109102.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '1671.2000122070312'},
#  '11005110101.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '4987.600006103516'},
#  '11005112101.0': {'idade': '55',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6249.599609375'},
#  '11005112102.0': {'idade': '48',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6249.599609375'},
#  '11005112103.0': {'idade': '21',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '6249.599609375'},
#  '11005112104.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '1562.39990234375'},
#  '11005112105.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '6249.599609375'},
#  '11005113101.0': {'idade': '45',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '1826.0'},
#  '11006001101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '5670.0'},
#  '11006001102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '5670.0'},
#  '11006002101.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '-1.0'},
#  '11006002102.0': {'idade': '51',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11006002103.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '4938.1201171875'},
#  '11006002104.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '-1.0'},
#  '11006003101.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '10544.400390625'},
#  '11006003102.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11006004101.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11006004102.0': {'idade': '38',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '3030.0'},
#  '11006005101.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '4863.599609375'},
#  '11006005102.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '15756.0'},
#  '11006006102.0': {'idade': '56',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11006006103.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '2965.7999877929688'},
#  '11006007101.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11006007102.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '7070.0'},
#  '11006007103.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '7514.400390625'},
#  '11006007104.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': '6241.80029296875'},
#  '11006007105.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '3636.0'},
#  '11006008102.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11006008103.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': ''},
#  '11006008104.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11006008105.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': ''},
#  '11006009101.0': {'idade': '57',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6605.400390625'},
#  '11006009102.0': {'idade': '47',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11006011101.0': {'idade': '51',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '39449.28125'},
#  '11006011102.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': ''},
#  '11006011103.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '6060.0'},
#  '11006011104.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '8484.0'},
#  '11006013101.0': {'idade': '57',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '1100.0'},
#  '11006013102.0': {'idade': '52',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11006013103.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '14.0',
#   'salario': '9600.0'},
#  '11006013104.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '5400.0'},
#  '11006013105.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '5880.0'},
#  '11006013106.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11007801101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '43680.0'},
#  '11007801102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11007802101.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': '8820.0'},
#  '11007802102.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '6702.0'},
#  '11007802103.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '721.0'},
#  '11007804101.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '115920.0'},
#  '11007808101.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '9090.0'},
#  '11007810101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '7272.0'},
#  '11007810102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '18815.8798828125'},
#  '11007811101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '15000.0'},
#  '11007811102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '750.0'},
#  '11007812101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '3020.0'},
#  '11007812102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '250.0'},
#  '11008601101.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9968.7001953125'},
#  '11008601102.0': {'idade': '21',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '8940.08984375'},
#  '11008603101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9600.0'},
#  '11008603102.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '4930.2001953125'},
#  '11008604101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '3078.47998046875'},
#  '11008604102.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11008606101.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '1600.0'},
#  '11008606102.0': {'idade': '51',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '43745.7578125'},
#  '11008606103.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9384.240234375'},
#  '11008606104.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '15912.0'},
#  '11008607101.0': {'idade': '58',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11008607102.0': {'idade': '57',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '122040.0'},
#  '11008608101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '8232.0'},
#  '11008608102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11008609101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '13.0',
#   'salario': '11220.0'},
#  '11008610101.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '28152.0'},
#  '11008610102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '25440.0'},
#  '11008611102.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11008612102.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '0.0'},
#  '11008613101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '38784.0'},
#  '11008613102.0': {'idade': '36',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11009401101.0': {'idade': '38',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '9600.0'},
#  '11009401102.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '7440.0'},
#  '11009402101.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '5940.0'},
#  '11009403101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '7733.8798828125'},
#  '11009403102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': '3600.0'},
#  '11009404101.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9020.639892578125'},
#  '11009405101.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '11309.759765625'},
#  '11009406101.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '9706.0'},
#  '11009406102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11009407101.0': {'idade': '59',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '12594.0'},
#  '11009407102.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6046.800048828125'},
#  '11009409101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '-1.0'},
#  '11009410101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '9504.0'},
#  '11009410102.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '4930.2001953125'},
#  '11009411101.0': {'idade': '48',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '7635.599609375'},
#  '11009411102.0': {'idade': '57',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '7272.0'},
#  '11009412101.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '18000.0'},
#  '11009412102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '5940.0'},
#  '11009413101.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '8484.0'},
#  '11009413102.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '3600.0'},
#  '11009413103.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '8484.0'},
#  '11010801103.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '2797.2001953125'},
#  '11010801104.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': '8325.0'},
#  '11010802101.0': {'idade': '36',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '4042.5'},
#  '11010802102.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '28704.0'},
#  '11010803101.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '7632.0'},
#  '11010803102.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '8152.0'},
#  '11010804101.0': {'idade': '57',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '46200.0'},
#  '11010805101.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '6600.0'},
#  '11010805102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '5184.0'},
#  '11010806101.0': {'idade': '47',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '20352.0'},
#  '11010807101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '74562.119140625'},
#  '11010807102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '32503.3203125'},
#  '11010808101.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '21696.0'},
#  '11010808102.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '2339.9599990844727'},
#  '11010809101.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '31188.0'},
#  '11010810101.0': {'idade': '47',
#   'sexo': 'mulher',
#   'anos_estudo': '',
#   'salario': '4944.0'},
#  '11010811101.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '48816.0'},
#  '11010812101.0': {'idade': '37',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '11340.0'},
#  '11010813101.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': '21696.0'},
#  '11010813102.0': {'idade': '39',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '-1.0'},
#  '11011601101.0': {'idade': '60',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '271200.0'},
#  '11011601102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '28882.798828125'},
#  '11011602101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '56952.0'},
#  '11011602102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '1260.0'},
#  '11011603101.0': {'idade': '60',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '50880.0'},
#  '11011603102.0': {'idade': '57',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11011603103.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '11700.0'},
#  '11011604103.0': {'idade': '37',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '31392.0'},
#  '11011608101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '12480.0'},
#  '11011608102.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '6240.0'},
#  '11011608105.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11011609101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '3450.0'},
#  '11011611101.0': {'idade': '47',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '4095.0'},
#  '11011611102.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': '9984.0'},
#  '11011612101.0': {'idade': '45',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '22488.958984375'},
#  '11011612102.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '22488.958984375'},
#  '11012401101.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '16272.0'},
#  '11012401102.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11012404101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '6801.599609375'},
#  '11012404102.0': {'idade': '47',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '8051.400390625'},
#  '11012406101.0': {'idade': '39',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '-1.0'},
#  '11012406102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '208.0'},
#  '11012407101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '11340.0'},
#  '11012407102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11012409101.0': {'idade': '58',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': ''},
#  '11012409102.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11012410101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '30426.240234375'},
#  '11012410102.0': {'idade': '41',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '48336.0'},
#  '11012411101.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6930.0'},
#  '11012412101.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11012412102.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '15120.0'},
#  '11012412106.0': {'idade': '49',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '13860.0'},
#  '11012413101.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11012413102.0': {'idade': '54',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '2496.0'},
#  '11012413103.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '10533.599609375'},
#  '11013201101.0': {'idade': '60',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '5670.0'},
#  '11013201103.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '871.5'},
#  '11013201104.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '2425.5'},
#  '11013201105.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11013202101.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '0.0'},
#  '11013202102.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '3261.2999877929688'},
#  '11013204101.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '7660.2001953125'},
#  '11013204102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '104923.0'},
#  '11013205101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '151200.0'},
#  '11013205102.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': ''},
#  '11013206101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '63600.0'},
#  '11013207101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '96245.7578125'},
#  '11013207102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '174245.765625'},
#  '11013208101.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '37440.0'},
#  '11013208102.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': ''},
#  '11013209101.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '60153.59765625'},
#  '11013209102.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '37800.0'},
#  '11013209103.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11013210101.0': {'idade': '52',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '-1.0'},
#  '11013210102.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '4305.599609375'},
#  '11013211101.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '11107.19921875'},
#  '11013213101.0': {'idade': '52',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '13200.0'},
#  '11013213102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11013213103.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11013213104.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11014001101.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6240.0'},
#  '11014001102.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '2205.0'},
#  '11014003101.0': {'idade': '36',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11014003102.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '5353.0'},
#  '11014003103.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11014003104.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '1693.199951171875'},
#  '11014004101.0': {'idade': '47',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '16380.0'},
#  '11014004102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': '21420.0'},
#  '11014005101.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '14176.0'},
#  '11014005102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11014007101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11014007102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '1939.2000732421875'},
#  '11014008101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '24240.0'},
#  '11014008102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '757.5'},
#  '11014010101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '27342.0'},
#  '11014010102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '660.0'},
#  '11014011101.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '17640.0'},
#  '11014011102.0': {'idade': '45',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '16572.0'},
#  '11014011103.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11014012101.0': {'idade': '58',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11014013101.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '5029.7998046875'},
#  '11014014101.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '2462.4000244140625'},
#  '11014014102.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '2906.0'},
#  '11014016101.0': {'idade': '45',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '8904.0'},
#  '11014016102.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11014017101.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '46176.0'},
#  '11014017102.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': ''},
#  '11014018101.0': {'idade': '46',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '12600.0'},
#  '11014018102.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '37440.0'},
#  '11014019101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '12928.0'},
#  '11014019102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '4848.0'},
#  '11014020101.0': {'idade': '39',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '13860.0'},
#  '11014020102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '4865.5'},
#  '11014021101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '24960.0'},
#  '11014021102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '630.0'},
#  '11014022102.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11014023101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '2625.0'},
#  '11014023102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '419.1499938964844'},
#  '11014024102.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '10080.0'},
#  '11014025101.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '9600.0'},
#  '11014026101.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '10200.0'},
#  '11014026102.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11014027101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '14400.0'},
#  '11014028101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '7200.0'},
#  '11015901101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '38400.0'},
#  '11015901102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11015903101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '103950.0'},
#  '11015903102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11015904101.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '95040.0'},
#  '11015904102.0': {'idade': '41',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '3180.0'},
#  '11015905101.0': {'idade': '47',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '46512.0'},
#  '11015905102.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11015906102.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': ''},
#  '11015907101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '38784.0'},
#  '11015907102.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '3600.0'},
#  '11015907104.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '300.0'},
#  '11015908102.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11015909101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '9504.0'},
#  '11015909102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11015910101.0': {'idade': '58',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11015910102.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '14688.0'},
#  '11015910103.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '14688.0'},
#  '11015911101.0': {'idade': '49',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '23760.0'},
#  '11015911102.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '52386.0'},
#  '11015913101.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '7200.0'},
#  '11015913102.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '4830.599609375'},
#  '11016701101.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '7560.0'},
#  '11016702101.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '27600.0'},
#  '11016702102.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '11500.0'},
#  '11016703101.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '0.0'},
#  '11016704101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '117600.0'},
#  '11016704102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '16888.0'},
#  '11016705101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '15912.0'},
#  '11016705102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '15912.0'},
#  '11016706102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '2550.0'},
#  '11016707101.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': '42595.203125'},
#  '11016707102.0': {'idade': '21',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '3000.0'},
#  '11016707105.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': ''},
#  '11016708101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9000.0'},
#  '11016708102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '750.0'},
#  '11016709101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '16560.0'},
#  '11016709102.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '8400.0'},
#  '11016710101.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '13464.0'},
#  '11016710102.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '7760.16015625'},
#  '11016711101.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '9696.0'},
#  '11016711102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '1804.199951171875'},
#  '11016713101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '16810.439453125'},
#  '11016713102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '5500.0'},
#  '11017501101.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '19980.0'},
#  '11017501102.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '13800.0'},
#  '11017502102.0': {'idade': '41',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '41400.0'},
#  '11017503101.0': {'idade': '46',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '24398.3984375'},
#  '11017503102.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '26504.3984375'},
#  '11017504101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '63600.0'},
#  '11017504102.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '12006.0'},
#  '11017505101.0': {'idade': '49',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '-1.0'},
#  '11017505102.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11017505103.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9240.0'},
#  '11017506101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '9858.0'},
#  '11017506102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11017507101.0': {'idade': '56',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '-1.0'},
#  '11017508101.0': {'idade': '60',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '10080.0'},
#  '11017508102.0': {'idade': '51',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '1512.0'},
#  '11017509101.0': {'idade': '58',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '13200.0'},
#  '11017509102.0': {'idade': '54',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '1335.60009765625'},
#  '11017509103.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11017510101.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6564.0'},
#  '11017510102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11017512101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '19620.0'},
#  '11017512102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '19620.0'},
#  '11017513101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '26160.0'},
#  '11017513102.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11018303101.0': {'idade': '52',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '11040.0'},
#  '11018304101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '13.0',
#   'salario': '13179.0'},
#  '11018304102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': '5544.0'},
#  '11018306101.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '999999.0'},
#  '11018306102.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11018306103.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '7920.0'},
#  '11018307102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '14.0',
#   'salario': ''},
#  '11018308101.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '13080.0'},
#  '11018308102.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11018310101.0': {'idade': '36',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '13628.9296875'},
#  '11018312103.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6540.0'},
#  '11018312104.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11019101101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '19080.0'},
#  '11019102101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '16560.0'},
#  '11019102102.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11019103101.0': {'idade': '59',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '2244.0'},
#  '11019103102.0': {'idade': '51',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '0.0'},
#  '11019105102.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11019105103.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11019106101.0': {'idade': '46',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '19080.0'},
#  '11019106102.0': {'idade': '36',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11019107101.0': {'idade': '47',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '-1.0'},
#  '11019107102.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '3360.0'},
#  '11019107103.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11019109101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '12818.3994140625'},
#  '11019109103.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '5395.5'},
#  '11019110101.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '8385.2998046875'},
#  '11019110102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11019111101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5995.0'},
#  '11019111102.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11019112102.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11019113101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '8393.0'},
#  '11019113102.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11020502101.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '3465.0'},
#  '11020502102.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '6954.2001953125'},
#  '11020503101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '15696.0'},
#  '11020503102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11020505101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '10080.0'},
#  '11020505102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11020506101.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '24720.0'},
#  '11020509101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '11550.0'},
#  '11020509102.0': {'idade': '43',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11020510101.0': {'idade': '59',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '22880.0'},
#  '11020510102.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11020511101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '14.0',
#   'salario': '10395.0'},
#  '11020512101.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': ''},
#  '11021301101.0': {'idade': '39',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5935.39990234375'},
#  '11021301102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '6016.7998046875'},
#  '11021303101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '10823.7001953125'},
#  '11021303102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '2520.0'},
#  '11021304102.0': {'idade': '38',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11021305101.0': {'idade': '48',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '3405.0'},
#  '11021305102.0': {'idade': '51',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '7416.0'},
#  '11021305104.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11021306101.0': {'idade': '49',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '6180.0'},
#  '11021306102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11021307101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5229.0'},
#  '11021307102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11021308101.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '',
#   'salario': '5695.2001953125'},
#  '11021310101.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '10080.0'},
#  '11021310102.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11021311101.0': {'idade': '51',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '37440.0'},
#  '11021311102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '3120.0'},
#  '11021312101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9450.0'},
#  '11021312102.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '2835.0'},
#  '11021313101.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '10710.0'},
#  '11021313102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11021313104.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6857.0'},
#  '11022101101.0': {'idade': '25',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '2616.0'},
#  '11022102101.0': {'idade': '45',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '14388.0'},
#  '11022102102.0': {'idade': '23',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11022103101.0': {'idade': '49',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '13680.0'},
#  '11022103102.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11022103103.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '1809.4000244140625'},
#  '11022104101.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '22050.0'},
#  '11022104102.0': {'idade': '36',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11022106102.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '0.0'},
#  '11022107101.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '2496.0'},
#  '11022107102.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '168.0'},
#  '11022108101.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '1604.0999755859375'},
#  '11022108102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11022109101.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '1932.0'},
#  '11022109102.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11022110101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5935.39990234375'},
#  '11022110102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '3274.7998046875'},
#  '11022111102.0': {'idade': '27',
# ...
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11043412102.0': {'idade': '58',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '22554.0'},
#  '11043413101.0': {'idade': '54',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '3744.0'},
#  '11043413102.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '0.0'},
#  '11043413103.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11044201101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '6090.0'},
#  '11044202101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '10458.0'},
#  '11044202102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11044202105.0': {'idade': '55',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11044203101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '9971.600006103516'},
#  '11044203102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': ''},
#  '11044204101.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '7632.0'},
#  '11044204105.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11044205101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '7170.399993896484'},
#  '11044205102.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '4128.8798828125'},
#  '11044206101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '15264.0'},
#  '11044206102.0': {'idade': '51',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11044207101.0': {'idade': '46',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '12720.0'},
#  '11044208101.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '6666.0'},
#  '11044208102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11044208104.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': ''},
#  '11044210102.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11044211101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '10920.0'},
#  '11044211102.0': {'idade': '36',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': '-1.0'},
#  '11044212101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '8835.75'},
#  '11044212102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '969.5999755859375'},
#  '11044213101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9122.400390625'},
#  '11044213102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': '6761.5'},
#  '11045001101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '10458.0'},
#  '11045001102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': '5670.0'},
#  '11045002101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '3206.7001953125'},
#  '11045002102.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '3675.0'},
#  '11045003101.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '17640.0'},
#  '11045003102.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11045003103.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11045004101.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '9.0',
#   'salario': '8008.0'},
#  '11045004102.0': {'idade': '21',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '2781.0'},
#  '11045005101.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '0.0'},
#  '11045005102.0': {'idade': '48',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6480.0'},
#  '11045006101.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6480.0'},
#  '11045006102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11045009101.0': {'idade': '59',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11045009102.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '6514.5'},
#  '11045010101.0': {'idade': '33',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '20604.0'},
#  '11045010102.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '18180.0'},
#  '11045011101.0': {'idade': '44',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11045014101.0': {'idade': '37',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '4980.0'},
#  '11045016102.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '654.0'},
#  '11045016103.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': ''},
#  '11046901101.0': {'idade': '22',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '16224.0'},
#  '11046902101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '37440.0'},
#  '11046903101.0': {'idade': '58',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11046904101.0': {'idade': '26',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '7131.599609375'},
#  '11046904102.0': {'idade': '25',
#   'sexo': 'mulher',
#   'anos_estudo': '10.0',
#   'salario': '2424.0'},
#  '11046905101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '7632.0'},
#  '11046905102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '0.0'},
#  '11046906101.0': {'idade': '36',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '8484.0'},
#  '11046906102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': '3636.0'},
#  '11046909101.0': {'idade': '56',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': '5229.0'},
#  '11046909102.0': {'idade': '32',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '10458.0'},
#  '11046909103.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11046912101.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '20.399999618530273'},
#  '11046912102.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '210.0'},
#  '11047701101.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '6000.0'},
#  '11047702101.0': {'idade': '60',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '27600.0'},
#  '11047703101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '16228.080078125'},
#  '11047703102.0': {'idade': '47',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11047705101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '33264.0'},
#  '11047707102.0': {'idade': '53',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '5346.0'},
#  '11047708101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '2400.0'},
#  '11047708102.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11047710101.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '3078.47998046875'},
#  '11047710102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11047712101.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '3078.47998046875'},
#  '11048501101.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '7380.0'},
#  '11048501102.0': {'idade': '22',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11048502101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '8848.0'},
#  '11048502102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '1440.0'},
#  '11048502103.0': {'idade': '24',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '2614.5'},
#  '11048502104.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': '3935.0'},
#  '11048502115.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11048503103.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11048503104.0': {'idade': '33',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '5524.2001953125'},
#  '11048504101.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '6774.0'},
#  '11048504102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': ''},
#  '11048505103.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11048505104.0': {'idade': '24',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '4930.2001953125'},
#  '11048506101.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6000.0'},
#  '11048506102.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11048507101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9504.0'},
#  '11048507102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11048510101.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '6915.599609375'},
#  '11048510102.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '4270.5'},
#  '11048511101.0': {'idade': '42',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '13273.56005859375'},
#  '11048511102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '10800.0'},
#  '11048512101.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '9.0',
#   'salario': '415.0'},
#  '11048513101.0': {'idade': '45',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11048513102.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6060.0'},
#  '11048513105.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '4074.0'},
#  '11049302101.0': {'idade': '56',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '50880.0'},
#  '11049302102.0': {'idade': '50',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11049303101.0': {'idade': '43',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '24564.0'},
#  '11049303102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11049304101.0': {'idade': '49',
#   'sexo': 'homem',
#   'anos_estudo': '15.0',
#   'salario': '52800.0'},
#  '11049304102.0': {'idade': '46',
#   'sexo': 'mulher',
#   'anos_estudo': '13.0',
#   'salario': '12420.0'},
#  '11049306101.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '9240.0'},
#  '11049307101.0': {'idade': '28',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '24564.0'},
#  '11049307102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '20340.0'},
#  '11049308101.0': {'idade': '32',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '35316.0'},
#  '11049308102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11049309101.0': {'idade': '39',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '6644.400390625'},
#  '11049311101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '4523.5'},
#  '11049311102.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11049312101.0': {'idade': '38',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '6300.0'},
#  '11049312102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11049313101.0': {'idade': '31',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '11990.0'},
#  '11049313102.0': {'idade': '27',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': ''},
#  '11050702101.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '7992.0'},
#  '11050702102.0': {'idade': '47',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '1792.0'},
#  '11050702103.0': {'idade': '26',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '2942.5'},
#  '11050704101.0': {'idade': '27',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '9936.0'},
#  '11050704102.0': {'idade': '31',
#   'sexo': 'mulher',
#   'anos_estudo': '15.0',
#   'salario': '9936.0'},
#  '11050706101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '13524.0'},
#  '11050706102.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11050707101.0': {'idade': '34',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '5796.0'},
#  '11050707102.0': {'idade': '34',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': '5796.0'},
#  '11050708101.0': {'idade': '30',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '7458.0'},
#  '11050708102.0': {'idade': '29',
#   'sexo': 'mulher',
#   'anos_estudo': '12.0',
#   'salario': '5886.0'},
#  '11050709101.0': {'idade': '45',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '1260.0'},
#  '11050709102.0': {'idade': '35',
#   'sexo': 'mulher',
#   'anos_estudo': '7.0',
#   'salario': '1260.0'},
#  '11050711101.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '25200.0'},
#  '11050711102.0': {'idade': '28',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11050712101.0': {'idade': '44',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '42828.0'},
#  '11050712102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '6300.0'},
#  '11050713101.0': {'idade': '29',
#   'sexo': 'homem',
#   'anos_estudo': '',
#   'salario': '2174.5498046875'},
#  '11050713102.0': {'idade': '30',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '5017.2001953125'},
#  '11051501101.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '7.0',
#   'salario': '7194.0'},
#  '11051502102.0': {'idade': '52',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '11025.0'},
#  '11051503101.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '359.70001220703125'},
#  '11051503104.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': ''},
#  '11051505101.0': {'idade': '20',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '8820.0'},
#  '11051506101.0': {'idade': '23',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '5670.0'},
#  '11051506102.0': {'idade': '20',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11051507101.0': {'idade': '35',
#   'sexo': 'homem',
#   'anos_estudo': '10.0',
#   'salario': '15696.0'},
#  '11051507102.0': {'idade': '37',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11051508101.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '4944.0'},
#  '11051508102.0': {'idade': '39',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': ''},
#  '11051509101.0': {'idade': '53',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '9984.0'},
#  '11051509102.0': {'idade': '40',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': ''},
#  '11051510101.0': {'idade': '42',
#   'sexo': 'mulher',
#   'anos_estudo': '5.0',
#   'salario': '2496.0'},
#  '11051510102.0': {'idade': '21',
#   'sexo': 'homem',
#   'anos_estudo': '6.0',
#   'salario': '7560.0'},
#  '11051511101.0': {'idade': '41',
#   'sexo': 'homem',
#   'anos_estudo': '11.0',
#   'salario': '8736.0'},
#  '11051511102.0': {'idade': '41',
#   'sexo': 'mulher',
#   'anos_estudo': '6.0',
#   'salario': ''},
#  '11051512101.0': {'idade': '49',
#   'sexo': 'mulher',
#   'anos_estudo': '8.0',
#   'salario': '6930.0'},
#  '11051513101.0': {'idade': '40',
#   'sexo': 'homem',
#   'anos_estudo': '12.0',
#   'salario': '11340.0'},
#  '11051513102.0': {'idade': '38',
#   'sexo': 'mulher',
#   'anos_estudo': '11.0',
#   'salario': ''},
#  '11051513106.0': {'idade': '37',
#   'sexo': 'homem',
#   'anos_estudo': '5.0',
#   'salario': '2520.0'},
#  '11052301101.0': {'idade': '48',
#   'sexo': 'homem',
#   'anos_estudo': '8.0',
#   'salario': '44100.0'},
#  ...}

# %%
'11027211101.0' in dict_table
# Out:
# True

# %%
dict_table['11027211101.0']
# Out:
# {'idade': '53', 'sexo': 'homem', 'anos_estudo': '5.0', 'salario': '7128.0'}

# %%
dict_table['11027211101.0']['anos_estudo']
# Out:
# '5.0'

# %%
dict_table['11027211101.0']['anos_estudo'] = '6'

# %%
dict_table['11027211101.0']
# Out:
# {'idade': '53', 'sexo': 'homem', 'anos_estudo': '6', 'salario': '7128.0'}

# %%
del dict_table['11027211101.0']

# %%
dict_table['11027211101.0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-7d8af068c742> in <module>()
# ----> 1 dict_table['11027211101.0']
#
# KeyError: '11027211101.0'

# %%
def create_text_histogram(txt):
    dictionary = {}
    i=0
    for x in set(txt): # função set
        dictionary[x] = txt.count(x)
    return dictionary

# %%
create_text_histogram(txt='teste de frase comprida para histograma')
# Out:
# {'r': 4,
#  'a': 6,
#  't': 3,
#  ' ': 5,
#  'o': 2,
#  'p': 2,
#  'i': 2,
#  'f': 1,
#  'e': 4,
#  'c': 1,
#  'h': 1,
#  'm': 2,
#  's': 3,
#  'g': 1,
#  'd': 2}

# %%
contagem_idades = {}

with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    header = next(data, None) # equivalente a i>0
    
    idades = []
    for row in data:
        idades.append(row[2])

# %%
histograma_idades = create_text_histogram(idades)

# %%
type(histograma_idades)
# Out:
# dict

# %%
histograma_idades
# Out:
# {'58': 969,
#  '56': 1087,
#  '43': 1699,
#  '21': 1987,
#  '37': 1712,
#  '52': 1244,
#  '24': 1892,
#  '50': 1461,
#  '44': 1688,
#  '27': 2017,
#  '51': 1260,
#  '22': 2034,
#  '60': 951,
#  '42': 1673,
#  '57': 1092,
#  '59': 999,
#  '23': 2014,
#  '53': 1249,
#  '38': 1727,
#  '25': 2014,
#  '48': 1505,
#  '29': 1943,
#  '49': 1429,
#  '45': 1627,
#  '40': 1732,
#  '54': 1221,
#  '30': 1996,
#  '55': 1133,
#  '47': 1446,
#  '31': 1796,
#  '41': 1552,
#  '32': 1852,
#  '36': 1723,
#  '39': 1759,
#  '20': 2104,
#  '35': 1672,
#  '46': 1566,
#  '34': 1737,
#  '33': 1812,
#  '28': 2056,
#  '26': 2040}

# %%
histograma_idades.keys()
# Out:
# dict_keys(['58', '56', '43', '21', '37', '52', '24', '50', '44', '27', '51', '22', '60', '42', '57', '59', '23', '53', '38', '25', '48', '29', '49', '45', '40', '54', '30', '55', '47', '31', '41', '32', '36', '39', '20', '35', '46', '34', '33', '28', '26'])

# %%
histograma_idades.values()
# Out:
# dict_values([969, 1087, 1699, 1987, 1712, 1244, 1892, 1461, 1688, 2017, 1260, 2034, 951, 1673, 1092, 999, 2014, 1249, 1727, 2014, 1505, 1943, 1429, 1627, 1732, 1221, 1996, 1133, 1446, 1796, 1552, 1852, 1723, 1759, 2104, 1672, 1566, 1737, 1812, 2056, 2040])

# %%
histograma_idades.items()
# Out:
# dict_items([('58', 969), ('56', 1087), ('43', 1699), ('21', 1987), ('37', 1712), ('52', 1244), ('24', 1892), ('50', 1461), ('44', 1688), ('27', 2017), ('51', 1260), ('22', 2034), ('60', 951), ('42', 1673), ('57', 1092), ('59', 999), ('23', 2014), ('53', 1249), ('38', 1727), ('25', 2014), ('48', 1505), ('29', 1943), ('49', 1429), ('45', 1627), ('40', 1732), ('54', 1221), ('30', 1996), ('55', 1133), ('47', 1446), ('31', 1796), ('41', 1552), ('32', 1852), ('36', 1723), ('39', 1759), ('20', 2104), ('35', 1672), ('46', 1566), ('34', 1737), ('33', 1812), ('28', 2056), ('26', 2040)])

# %%
for key in sorted(histograma_idades.keys()):
    print("%s: %s" % (key, histograma_idades[key]))
# Out:
# 20: 2104
# 21: 1987
# 22: 2034
# 23: 2014
# 24: 1892
# 25: 2014
# 26: 2040
# 27: 2017
# 28: 2056
# 29: 1943
# 30: 1996
# 31: 1796
# 32: 1852
# 33: 1812
# 34: 1737
# 35: 1672
# 36: 1723
# 37: 1712
# 38: 1727
# 39: 1759
# 40: 1732
# 41: 1552
# 42: 1673
# 43: 1699
# 44: 1688
# 45: 1627
# 46: 1566
# 47: 1446
# 48: 1505
# 49: 1429
# 50: 1461
# 51: 1260
# 52: 1244
# 53: 1249
# 54: 1221
# 55: 1133
# 56: 1087
# 57: 1092
# 58: 969
# 59: 999
# 60: 951

# %% [markdown]
# ### Definindo uma função para calcular a Mediana

# %%
def median(l):
    half = (len(l)) // 2
    l.sort()
    if not len(l) % 2:
        return (l[half - 1] + l[half]) / 2.0
    return l[half]

# %% [markdown]
# ### Aplicando para as idades do nosso DataSet

# %%
idades = list(map(int,idades))
median(idades)
# Out:
# 37.0

# %% [markdown]
# ### Moda
#
#
# Em estatística, moda é uma das medidas de tendência central de um conjunto de dados, assim como a média e a mediana. Ela pode ser definida em moda amostral e populacional.
#
# Em relação à primeira delas, a moda amostral de um conjunto de dados trata do valor que ocorre com maior frequência ou o valor mais comum em um conjunto de dados. Moda é especialmente útil quando os valores ou as observações não são numéricos, casos em que a média e a mediana não podem ser definidas.
#
# Moda amostral não é necessariamente única como média ou mediana. Amostras que possuem uma moda são chamadas unimodais. Por exemplo, a amostra {1, 2, 3, 5, 5, 6, 7} tem moda 5. Amostras que possuem duas modas são chamadas bimodais. Por exemplo, a amostra {1, 2, 3, 5, 5, 6, 6} tem modas 5 e 6. Amostras que possuem várias modas são chamadas multimodais. Por exemplo, a amostra {1, 2 3, 5, 5, 6, 6, 7, 7} tem modas 5, 6 e 7. Amostras que não possuem moda são chamadas amodais. Por exemplo, a amostra {1, 3, 2, 5, 7, 6} não tem moda.
#
# Por exemplo, a moda de [0,1,1,2,2,2,2,3,3,4,4,4,5] é 2.
#
# A moda não é necessariamente única. Pode ser que existam dois valores diferentes que sejam os mais frequentes. Por exemplo, no caso de [10, 13, 13, 20, 20], tanto 13 como 20 são a moda.
#
# <br>
# <img src="img/moda2.png">
# <br>

# %% [markdown]
# ### Calculando a moda

# %%
inverse = [(value, key) for key, value in histograma_idades.items()]
print ("O valor mais frequente para as idades é",max(inverse)[1])
# Out:
# O valor mais frequente para as idades é 20

# %%
print ("O número de pessoas com",max(inverse)[1],"anos de idade é",max(inverse)[0])
# Out:
# O número de pessoas com 20 anos de idade é 2104

# %% [markdown]
# ### Vamos criar uma função para procurar a pessoa mais velha da base

# %%
max_age = None
oldest_person = None

input_file = csv.DictReader(open(r'data/data.csv', 'r'))

for row in input_file:
    age = int(row["idade"])
    if max_age == None or max_age < age:
        max_age = age
        oldest_person = row["id"]

if max_age != None:
    print("A pessoa mais velha na base é o id %s, que tem %d anos." % (oldest_person, max_age))
else:
    print("Não tem ninguém nesse arquivo")
# Out:
# A pessoa mais velha na base é o id 11002710101.0, que tem 60 anos.

# %% [markdown]
# ### Como criar uma função para procurar a pessoa mais nova da base?

# %%
min_age = None
oldest_person = None

input_file = csv.DictReader(open(r'data/data.csv', 'r'))

for row in input_file:
    age = int(row["idade"])
    if min_age == None or min_age > age:
        min_age = age
        youngest_person = row["id"]

if min_age != None:
    print("A pessoa mais nova na base é o id %s, que tem %d anos." % (youngest_person, min_age))
else:
    print("Não tem ninguém nesse arquivo")
# Out:
# A pessoa mais nova na base é o id 11001907102.0, que tem 20 anos.

# %% [markdown]
# ## Prévia da resposta para o nosso problema. Os homens ganham mais do que as mulheres? Quanto?

# %%
with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    lista_homem = []
    somatorio = 0.0
    for i, line in enumerate(data):
        if i>0:
            if line[3] == 'homem':
                somatorio +=  tira_zero(line[6])
                lista_homem.append(line[6])
            

media_sal_homem = round(somatorio/len(lista_homem),2)

print(f'Média salário homem: {media_sal_homem}')
# Out:
# Média salário homem: 19282.29

# %%
with open(r'data/data.csv', 'r') as data_csv:
    data = csv.reader(data_csv)
    
    lista_mulher = []
    somatorio = 0.0
    for i, line in enumerate(data):
        if i>0:
            if line[3] == 'mulher':
                somatorio +=  tira_zero(line[6])
                lista_mulher.append(line[6])
            

media_sal_mulher = round(somatorio/len(lista_mulher),2)

print(f'Média salário mulher: {media_sal_mulher}')
# Out:
# Média salário mulher: 9258.33

# %% [markdown]
# ### Para este DataSet, em média as mulheres ganham mais que os homens.
